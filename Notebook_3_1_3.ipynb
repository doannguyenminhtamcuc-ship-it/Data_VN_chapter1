# %% [markdown]
# <a href="https://colab.research.google.com/github/doannguyenminhtamcuc-ship-it/Data_VN_chapter1/blob/main/Notebook_3_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.1.3. Khám phá cấu trúc dữ liệu

# %%
import pandas as pd

df = pd.read_csv('/content/Employment OECD INDUSTRY.csv')
display(df.head())
# Out:
#   Country  Year  Gender                                  Economic activity  \
# 0    OECD  2013  Female               A. Agriculture; forestry and fishing
# 1    OECD  2013  Female                                   C. Manufacturing
# 2    OECD  2013  Female                                    F. Construction
# 3    OECD  2013  Female  G. Wholesale and retail trade; repair of motor...
# 4    OECD  2013  Female                      H. Transportation and storage
#
#    Employment Thousands
# 0             7263.7368
# 1            16442.3368
# 2             2332.8045
# 3            26490.8310
# 4             3015.7303
